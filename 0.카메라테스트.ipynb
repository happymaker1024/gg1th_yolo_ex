# %% [markdown]
# # 카메라 실시간테스트

# %%
import cv2

cap = cv2.VideoCapture(0, cv2.CAP_V4L2)

print("카메라 열림:", cap.isOpened())

if cap.isOpened():
    ret, frame = cap.read()
    print("프레임 읽기:", ret)

cap.release()
# Out:
# 카메라 열림: True
# 프레임 읽기: False
# [ WARN:0@10.365] global cap_v4l.cpp:1049 tryIoctl VIDEOIO(V4L2:/dev/video0): select() timeout.

# %%
import cv2

cap = cv2.VideoCapture(0, cv2.CAP_V4L2)

cap.set(
    cv2.CAP_PROP_FOURCC,
    cv2.VideoWriter_fourcc(*'YUYV')
)

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
cap.set(cv2.CAP_PROP_FPS, 30)

print("카메라 열림:", cap.isOpened())

print("실제 WIDTH :", cap.get(cv2.CAP_PROP_FRAME_WIDTH))
print("실제 HEIGHT:", cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print("실제 FPS   :", cap.get(cv2.CAP_PROP_FPS))

ret, frame = cap.read()

print("프레임 읽기:", ret)

if ret:
    print("frame shape:", frame.shape)

cap.release()
# Out:
# 카메라 열림: True
# 실제 WIDTH : 640.0
# 실제 HEIGHT: 480.0
# 실제 FPS   : 30.0
# 프레임 읽기: False
# [ WARN:0@286.897] global cap_v4l.cpp:1049 tryIoctl VIDEOIO(V4L2:/dev/video0): select() timeout.
